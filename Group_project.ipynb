# %% [markdown]
# <a href="https://colab.research.google.com/github/saiteja-hash/Ai_enbaled_systems/blob/main/Group_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Section 1: Dataset loading and Cleaning

# %%
# modules
# !pip install ucimlrepo
# !pip install scikit-surprise pandas
import pandas as pd
from ucimlrepo import fetch_ucirepo
from surprise import SVD, dataset, Reader, accuracy
from surprise.model_selection import train_test_split
# Out:
# Collecting ucimlrepo
#   Downloading ucimlrepo-0.0.7-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from ucimlrepo) (2.2.3)
# Requirement already satisfied: certifi>=2020.12.5 in /usr/local/lib/python3.13/dist-packages (from ucimlrepo) (2026.7.22)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.0.0->ucimlrepo) (2026.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)
# Downloading ucimlrepo-0.0.7-py3-none-any.whl (8.0 kB)
# Installing collected packages: ucimlrepo
# Successfully installed ucimlrepo-0.0.7
# Collecting scikit-surprise
#   Downloading scikit_surprise-1.1.5-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (2.2.3)
# Requirement already satisfied: joblib>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from scikit-surprise) (1.6.0)
# Requirement already satisfied: numpy>=1.24.1 in /usr/local/lib/python3.13/dist-packages (from scikit-surprise) (2.1.3)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.13/dist-packages (from scikit-surprise) (1.16.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas) (2026.3)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib>=1.4.0->scikit-surprise) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading scikit_surprise-1.1.5-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 32.1 MB/s eta 0:00:00
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.5

# %%
#loading Dataset
heart_disease = fetch_ucirepo(id=45)

X = heart_disease.data.features
y = heart_disease.data.targets

# %%
# Combining data
df = pd.concat([X, y], axis=1)

# %%
# Displaying rows
display(df.head())

# Displaying shape
print("Shape:", df.shape)

# Displaying details
df.info()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#     ca  thal  num
# 0  0.0   6.0    0
# 1  3.0   3.0    2
# 2  2.0   7.0    1
# 3  0.0   3.0    0
# 4  0.0   3.0    0
# Shape: (303, 14)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        299 non-null    float64
#  12  thal      301 non-null    float64
#  13  num       303 non-null    int64
# dtypes: float64(3), int64(11)
# memory usage: 33.3 KB

# %%
# Displaying summary
df.describe(include="all")
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769  246.693069    0.148515
# std      9.038662    0.467299    0.960126   17.599748   51.776918    0.356198
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# std      0.994971   22.875003    0.469794    1.161075    0.616226    0.937438
# min      0.000000   71.000000    0.000000    0.000000    1.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    2.000000    0.000000
# 75%      2.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    3.000000    3.000000
#
#              thal         num
# count  301.000000  303.000000
# mean     4.734219    0.937294
# std      1.939706    1.228536
# min      3.000000    0.000000
# 25%      3.000000    0.000000
# 50%      3.000000    0.000000
# 75%      7.000000    2.000000
# max      7.000000    4.000000

# %%
# Counting missing values
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# num         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Displaying data types
print(df.dtypes)
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca          float64
# thal        float64
# num           int64
# dtype: object

# %% [markdown]
# #  Section 2: EDA

# %% [markdown]
# ### 1. Target Variable Analysis

# %%
# Check the distribution of the target variable distribution and check for any class imbalances

# %% [markdown]
# ### 2. Categorical Features Analysis

# %%
# Visulaize and identify the the categories that are associated with the elevated risk of heart disease.

# %% [markdown]
# ### 3. Numerical Features Analysis

# %%
# Check how numerical data distribution differ between patients with and without heart disease

# %% [markdown]
# ### 4. Correlation Analysis

# %%
# Check for Corelation between feature and target variables

# %% [markdown]
# ### 5. Outlier detection

# %%
 # Check for Any outliers present in the data

# %% [markdown]
# # Section 3: Feature Engineering

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# 1. Handle Missing Values
# The EDA showed 'ca' has 4 missing values and 'thal' has 2.
# We use the median/mode since these are discrete/categorical features.
df['ca'] = df['ca'].fillna(df['ca'].median())
df['thal'] = df['thal'].fillna(df['thal'].mode()[0])

# 2. Target Variable Transformation
# The target 'num' ranges from 0 to 4. For standard prediction,
# it is highly recommended to binarize this (0: No disease, 1: Disease present).
df['target'] = df['num'].apply(lambda x: 1 if x > 0 else 0)
df = df.drop('num', axis=1)

# 3. Categorical Encoding (One-Hot Encoding)
# 'cp', 'restecg', 'slope', and 'thal' are categorical features represented by integers.
# Leaving them as integers tricks the model into thinking they have sequential weight.
categorical_cols = ['cp', 'restecg', 'slope', 'thal']
df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

# 4. Feature Scaling
# Continuous variables have vastly different ranges (e.g., chol up to 564, oldpeak up to 6.2).
continuous_cols = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']
scaler = StandardScaler()
df[continuous_cols] = scaler.fit_transform(df[continuous_cols])

# Displaying updated details
print("Updated Shape:", df.shape)
display(df.head())
# Out:
# Updated Shape: (303, 19)
#         age  sex  trestbps      chol  fbs   thalach  exang   oldpeak   ca  \
# 0  0.948726    1  0.757525 -0.264900    1  0.017197      0  1.087338  0.0
# 1  1.392002    1  1.611220  0.760415    0 -1.821905      1  0.397182  3.0
# 2  1.392002    1 -0.665300 -0.342283    0 -0.902354      1  1.346147  2.0
# 3 -1.932564    1 -0.096170  0.063974    0  1.637359      0  2.122573  0.0
# 4 -1.489288    0 -0.096170 -0.825922    0  0.980537      0  0.310912  0.0
#
#    target   cp_2   cp_3   cp_4  restecg_1  restecg_2  slope_2  slope_3  \
# 0       0  False  False  False      False       True    False     True
# 1       1  False  False   True      False       True     True    False
# 2       1  False  False   True      False       True     True    False
# 3       0  False   True  False      False      False    False     True
# 4       0   True  False  False      False       True    False    False
#
#    thal_6.0  thal_7.0
# 0      True     False
# 1     False     False
# 2     False      True
# 3     False     False
# 4     False     False

# %% [markdown]
# # Section 4: Initial Model Development

# %%
# 1. Reshape data into exactly 3 columns: [patient_id, feature_or_treatment_id, rating]
# Example: Long-format dataframe with patient encounters
df_surprise = pd.DataFrame({
    'user_id': patient_ids,       # e.g., Patient ID
    'item_id': feature_or_meds,   # e.g., Treatment/Diagnosis Code
    'rating': target_values       # e.g., Outcome / Risk Score (0 to 1)
})

# 2. Convert to Surprise Dataset
reader = Reader(rating_scale=(0, 1))
data = Dataset.load_from_df(df_surprise[['user_id', 'item_id', 'rating']], reader)

# 3. Train-test split
trainset, testset = train_test_split(data, test_size=0.25, random_state=42)

# 4. Train SVD and evaluate
algo = SVD(random_state=42)
algo.fit(trainset)
predictions = algo.test(testset)

# 5. Metrics
rmse = accuracy.rmse(predictions)
mae = accuracy.mae(predictions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2736/3889665289.py in <cell line: 0>()
#       2 # Example: Long-format dataframe with patient encounters
#       3 df_surprise = pd.DataFrame({
# ----> 4     'user_id': patient_ids,       # e.g., Patient ID
#       5     'item_id': feature_or_meds,   # e.g., Treatment/Diagnosis Code
#       6     'rating': target_values       # e.g., Outcome / Risk Score (0 to 1)
#
# NameError: name 'patient_ids' is not defined

# %% [markdown]
# # Section 5: Initial Model Evaluation
